# %%
#Importing the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the data
df = pd.read_csv(r'C:\Users\Yogesh\Desktop\Kaggle_Projects\Euro_2020\euro2020.csv')

# %%
#Checking the dataset
df.head()
# Out:
#               Player         Country Position  Match played  Goals  \
# 0  Cristiano Ronaldo        Portugal        F             4      5
# 1      Patrik Schick  Czech Republic        F             5      5
# 2      Karim Benzema          France        F             4      4
# 3      Emil Forsberg          Sweden        M             4      4
# 4      Romelu Lukaku         Belgium        F             5      4
#
#    Right foot goals  Left foot goals  Header goals  Assists  Total attempts  \
# 0               3.0              2.0           0.0      1.0            16.0
# 1               1.0              3.0           1.0      0.0            16.0
# 2               2.0              2.0           1.0      0.0            11.0
# 3               2.0              2.0           0.0      0.0            14.0
# 4               2.0              2.0           0.0      0.0            13.0
#
#    ...  Top speed  Passing accuracy  Distance covered  Clearence attempted  \
# ...

# %%
#Shape of the data - rows and columns
df.shape
# Out:
# (59, 27)

# %%
df.columns
# Out:
# Index(['Player', 'Country', 'Position', 'Match played', 'Goals',
#        'Right foot goals', 'Left foot goals', 'Header goals', 'Assists',
#        'Total attempts', 'On target', 'Off target', 'Woodwork', 'Shot blocks',
#        'Avg gpg', 'Fouls suffered', 'Fouls committed', 'Top speed',
#        'Passing accuracy', 'Distance covered', 'Clearence attempted',
#        'Balls recovered', 'Tackels', 'Blocks', 'Yellow cards', 'Red cards',
#        'Minutes played'],
#       dtype='object')

# %%
#To check the mean, median and other percentiles of the numerical data
df.describe()
# Out:
#        Match played      Goals  Right foot goals  Left foot goals  \
# count     59.000000  59.000000         57.000000        57.000000
# mean       4.813559   1.338983          0.649123         0.456140
# std        1.166701   1.504134          0.876096         0.757585
# min        2.000000   0.000000          0.000000         0.000000
# 25%        4.000000   0.000000          0.000000         0.000000
# 50%        4.000000   1.000000          0.000000         0.000000
# 75%        6.000000   2.000000          1.000000         1.000000
# max        7.000000   5.000000          3.000000         3.000000
#
#        Header goals    Assists  Total attempts  On target  Off target  \
# count     57.000000  58.000000       58.000000  56.000000   56.000000
# mean       0.210526   0.741379        7.620690   2.982143    2.982143
# std        0.490511   1.018433        5.634566   2.673038    2.576051
# min        0.000000   0.000000        0.000000   0.000000    0.000000
# ...

# %%
#Checking the number of Null values in each column
df.isnull().sum()
# Out:
# Player                  0
# Country                 0
# Position                1
# Match played            0
# Goals                   0
# Right foot goals        2
# Left foot goals         2
# Header goals            2
# Assists                 1
# Total attempts          1
# On target               3
# Off target              3
# Woodwork                4
# Shot blocks             3
# Avg gpg                 0
# Fouls suffered          4
# Fouls committed         0
# Top speed               0
# Passing accuracy        0
# Distance covered        0
# Clearence attempted     9
# Balls recovered         4
# Tackels                 6
# Blocks                 40
# Yellow cards            3
# Red cards               3
# Minutes played          0
# dtype: int64

# %%
#Checking the percentage of Null values in each column
df.isnull().sum()/len(df)*100
# Out:
# Player                  0.000000
# Country                 0.000000
# Position                1.694915
# Match played            0.000000
# Goals                   0.000000
# Right foot goals        3.389831
# Left foot goals         3.389831
# Header goals            3.389831
# Assists                 1.694915
# Total attempts          1.694915
# On target               5.084746
# Off target              5.084746
# Woodwork                6.779661
# Shot blocks             5.084746
# Avg gpg                 0.000000
# Fouls suffered          6.779661
# Fouls committed         0.000000
# Top speed               0.000000
# Passing accuracy        0.000000
# Distance covered        0.000000
# Clearence attempted    15.254237
# Balls recovered         6.779661
# Tackels                10.169492
# Blocks                 67.796610
# Yellow cards            5.084746
# Red cards               5.084746
# Minutes played          0.000000
# dtype: float64

# %%
#Changing the Position column's acronyms
df['Position']=df['Position'].map({'F':'Forward','M':'Midfielder','D':'Defender'})

# %%
#Imputing the missing value of Position column with Mode
df['Position']=df['Position'].fillna(df['Position'].mode()[0])

# %%
#Replacing the rest of the missing values with Zeros, as it is possible that the rest of the values are zero.
#For example : Right foot goals of a player can be zero, Assists can be zero etc.
df = df.replace(np.NaN, 0)

# %%
#Cross checking if all the abovementioned steps are completed 
df.head(5)
# Out:
#               Player         Country    Position  Match played  Goals  \
# 0  Cristiano Ronaldo        Portugal     Forward             4      5
# 1      Patrik Schick  Czech Republic     Forward             5      5
# 2      Karim Benzema          France     Forward             4      4
# 3      Emil Forsberg          Sweden  Midfielder             4      4
# 4      Romelu Lukaku         Belgium     Forward             5      4
#
#    Right foot goals  Left foot goals  Header goals  Assists  Total attempts  \
# 0               3.0              2.0           0.0      1.0            16.0
# 1               1.0              3.0           1.0      0.0            16.0
# 2               2.0              2.0           1.0      0.0            11.0
# 3               2.0              2.0           0.0      0.0            14.0
# 4               2.0              2.0           0.0      0.0            13.0
#
#    ...  Top speed  Passing accuracy  Distance covered  Clearence attempted  \
# ...

# %%
#Cross cehcking the percentage of Null values - Now they are all 0
df.isnull().sum()/len(df)*100
# Out:
# Player                 0.0
# Country                0.0
# Position               0.0
# Match played           0.0
# Goals                  0.0
# Right foot goals       0.0
# Left foot goals        0.0
# Header goals           0.0
# Assists                0.0
# Total attempts         0.0
# On target              0.0
# Off target             0.0
# Woodwork               0.0
# Shot blocks            0.0
# Avg gpg                0.0
# Fouls suffered         0.0
# Fouls committed        0.0
# Top speed              0.0
# Passing accuracy       0.0
# Distance covered       0.0
# Clearence attempted    0.0
# Balls recovered        0.0
# Tackels                0.0
# Blocks                 0.0
# Yellow cards           0.0
# Red cards              0.0
# Minutes played         0.0
# dtype: float64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### > Univariate Analysis:

# %%
#Pie chart for the percentage of Positions in the dataset

plt.figure(figsize=(9,7))
df.Position.value_counts().plot(kind='pie', autopct='%.2f',colors=['tomato', 'gold', 'skyblue'])
plt.show()

# %% [markdown]
# ##### Most of the player in the dataset play in the Position of Midfielders

# %%
#Pie chart for the percentage of Average Goals per game in the dataset

plt.figure(figsize=(12,10))
df['Avg gpg'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %% [markdown]
# ##### In most of the games the average goal scored was 0

# %%
#Comparing the various percentiles of  'On target' and 'Off target'

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(x='On target',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='Off target',data=df)
plt.show()

# %% [markdown]
# ##### Seems like the On and Off targets have similar median, but at 75% the On target seems better.

# %% [markdown]
# #### > Bivariate Analysis

# %%
# Players vs Goals
#Where goals are greater than Zero - 0
df1 = df[df['Goals']>0]

#Plotting a barplot
plt.figure(figsize=(20,15))
plt.title('Total goals by players', fontsize=20)
sns.barplot(x='Player',y='Goals',data=df1, order=df1.sort_values('Goals',ascending = False).Player)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Again Ronaldo is a top scorer with most number of goals

# %%
# Country vs Goals
#Where goals are greater than Zero - 0

#Plotting a barplot
plt.figure(figsize=(15,8))
plt.title('Total goals by Countries', fontsize=20)
sns.barplot(x='Country',y='Goals',data=df1 ,estimator=sum, ci=None)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### England owns the first place in most number of goals

# %%
# Right foot goals vs Left foot goals
plt.figure(figsize=(14,6))
sns.set_theme(style="whitegrid")
plt.subplot(1,2,1)
plt.title("Right foot goals", fontsize=20)
sns.barplot(x='Right foot goals',y='Goals',data=df ,estimator=sum, ci=None)
plt.subplot(1,2,2)
plt.title("Left foot goals", fontsize=20)
sns.barplot(x='Left foot goals',y='Goals',data=df ,estimator=sum, ci=None)
plt.show()

# %% [markdown]
# ##### Right foot seems to perform better.

# %%
# Player vs Assists
#Where Assists are greater than Zero - 0
df_Assists = df[df['Assists']>0]

plt.figure(figsize=(10,8))
sns.set_theme(style="whitegrid")
plt.title('Total Assists by players', fontsize=20)
sns.barplot(x='Player',y='Assists',data=df_Assists ,estimator=sum, ci=None,order=df_Assists.sort_values(by=['Assists'], ascending=False).Player)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Seteve Zuber takes the crown with most assists

# %%
# Country vs Yellow cards

plt.figure(figsize=(10,6))
sns.set_theme(style="whitegrid")
sns.barplot(x='Country',y='Yellow cards',data=df,estimator=sum, ci=None)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### The referees don't seem too happy with Italy

# %%
#Player vs Fouls committed

plt.figure(figsize=(16,8))
plt.title('Total Fouls committed by players', fontsize=20)
sns.barplot(x='Player',y='Fouls committed',data=df,estimator=sum, ci=None,order=df.sort_values(by=['Fouls committed'], ascending=False).Player)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Kalvin hillips won't be too happy with this achievement

# %%
plt.figure(figsize=(12,8))
plt.title('Fastest players', fontsize=20)
sns.barplot(x='Player',y='Top speed',data=df,estimator=sum, ci=None,order=df.sort_values(by=['Top speed'], ascending=False).Player)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### There are many fast players, seperated subtly

# %%
#Player vs Minutes played

plt.figure(figsize=(15,8))
plt.title('Total minutes played by players', fontsize=20)
sns.barplot(x='Player',y='Minutes played',data=df,estimator=sum, ci=None,order=df.sort_values(by=['Minutes played'], ascending=False).Player)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Jorginho tops the chart

# %%
# Player vs Match played

plt.figure(figsize=(15,8))
plt.title('Total matches played by players', fontsize=20)
sns.barplot(x='Player',y='Match played',data=df,estimator=sum, ci=None,order=df.sort_values(by=['Match played'], ascending=False).Player)
plt.xticks(rotation = 90)
plt.show()

# %%
#Total goals scored by different Postions for their countries

plt.figure(figsize=(20,10))
plt.title('Total goals scored by Postions for countries', fontsize=20)
sns.barplot(x='Country',y='Goals',hue='Position',data=df, ci=None)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### The forwards are doing their job with more number of goals.
